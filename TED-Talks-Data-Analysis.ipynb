# %% [markdown]
# # TED Talks Data Analysis
# This project contains a detailed analysis of the information about all talks including number of views, number of comments, descriptions, speakers and titles

# %% [markdown]
# ## Data Preparation and Cleaning
# The first step is to go through our data and clean it. In this step all the peculiar data values and missing data will be taken care of and the final data set to be analysed will be prepared.

# %%
import pandas as pd
ted_talks_raw_df = pd.read_csv(r"C:\Users\heram\Downloads\ted_main.csv")
ted_talks_raw_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 0          TED2006  1140825600         60         Ken Robinson
# 1          TED2006  1140825600         43              Al Gore
# 2          TED2006  1140739200         26          David Pogue
# 3          TED2006  1140912000         35        Majora Carter
# 4          TED2006  1140566400         48         Hans Rosling
# ...            ...         ...        ...                  ...
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 0             Ken Robinson: Do schools kill creativity?            1
# 1                  Al Gore: Averting the climate crisis            1
# 2                         David Pogue: Simplicity sells            1
# 3                    Majora Carter: Greening the ghetto            1
# 4         Hans Rosling: The best stats you've ever seen            1
# ...                                                 ...          ...
# 2545  Duarte Geraldino: What we're missing in the de...            1
# 2546  Armando Azua-Bustos: The most Martian place on...            1
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# 0         1151367060  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1         1151367060  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2         1151367060  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3         1151367060  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4         1151440680  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...              ...                                                ...
# 2545      1505851216  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546      1505919737  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547      1506006095  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548      1506024042  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549      1506092422  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# ...                                                 ...
# 2545  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2546  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2547  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2548  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                         speaker_occupation  \
# 0                          Author/educator
# 1                         Climate advocate
# 2                     Technology columnist
# 3       Activist for environmental justice
# 4     Global health expert; data visionary
# ...                                    ...
# 2545                            Journalist
# 2546                        Astrobiologist
# 2547                     Robotics engineer
# 2548                   Public intellectual
# 2549                         Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 1     ['alternative energy', 'cars', 'climate change...
# 2     ['computers', 'entertainment', 'interface desi...
# 3     ['MacArthur grant', 'activism', 'business', 'c...
# 4     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                 ...
# 2545  ['TED Residency', 'United States', 'community'...
# 2546  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2547  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2548  ['Internet', 'TEDx', 'United States', 'communi...
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# 3                                   Greening the ghetto
# 4                       The best stats you've ever seen
# ...                                                 ...
# 2545  What we're missing in the debate about immigra...
# 2546                    The most Martian place on Earth
# 2547  What intelligent machines can learn from a sch...
# 2548       A black man goes undercover in the alt-right
# 2549  How a video game might help us build better ci...
#
#                                                     url     views
# 0     https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1     https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2     https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3     https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4     https://www.ted.com/talks/hans_rosling_shows_t...  12005869
# ...                                                 ...       ...
# 2545  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2546  https://www.ted.com/talks/armando_azua_bustos_...    417470
# 2547  https://www.ted.com/talks/radhika_nagpal_what_...    375647
# 2548  https://www.ted.com/talks/theo_e_j_wilson_a_bl...    419309
# 2549  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
# [2550 rows x 17 columns]

# %%
ted_talks_raw_df.describe()
# Out:
#           comments     duration     film_date    languages  num_speaker  \
# count  2550.000000  2550.000000  2.550000e+03  2550.000000  2550.000000
# mean    191.562353   826.510196  1.321928e+09    27.326275     1.028235
# std     282.315223   374.009138  1.197391e+08     9.563452     0.207705
# min       2.000000   135.000000  7.464960e+07     0.000000     1.000000
# 25%      63.000000   577.000000  1.257466e+09    23.000000     1.000000
# 50%     118.000000   848.000000  1.333238e+09    28.000000     1.000000
# 75%     221.750000  1046.750000  1.412964e+09    33.000000     1.000000
# max    6404.000000  5256.000000  1.503792e+09    72.000000     5.000000
#
#        published_date         views
# count    2.550000e+03  2.550000e+03
# mean     1.343525e+09  1.698297e+06
# std      9.464009e+07  2.498479e+06
# min      1.151367e+09  5.044300e+04
# 25%      1.268463e+09  7.557928e+05
# 50%      1.340935e+09  1.124524e+06
# 75%      1.423432e+09  1.700760e+06
# max      1.506092e+09  4.722711e+07

# %% [markdown]
# It can be seen that the number of languages for certain entries are 0, which is not possible, hence we will be replacing these with the value 1. This is because these Ted Talks must be present in atleast 1 language.

# %%
ted_talks_raw_df.loc[ted_talks_raw_df['languages'] == 0, 'languages'] = 1
ted_talks_raw_df.describe()
# Out:
#           comments     duration     film_date    languages  num_speaker  \
# count  2550.000000  2550.000000  2.550000e+03  2550.000000  2550.000000
# mean    191.562353   826.510196  1.321928e+09    27.360000     1.028235
# std     282.315223   374.009138  1.197391e+08     9.468279     0.207705
# min       2.000000   135.000000  7.464960e+07     1.000000     1.000000
# 25%      63.000000   577.000000  1.257466e+09    23.000000     1.000000
# 50%     118.000000   848.000000  1.333238e+09    28.000000     1.000000
# 75%     221.750000  1046.750000  1.412964e+09    33.000000     1.000000
# max    6404.000000  5256.000000  1.503792e+09    72.000000     5.000000
#
#        published_date         views
# count    2.550000e+03  2.550000e+03
# mean     1.343525e+09  1.698297e+06
# std      9.464009e+07  2.498479e+06
# min      1.151367e+09  5.044300e+04
# 25%      1.268463e+09  7.557928e+05
# 50%      1.340935e+09  1.124524e+06
# 75%      1.423432e+09  1.700760e+06
# max      1.506092e+09  4.722711e+07

# %%
selected_columns = [ 
    #The number of first level comments made on the talk    
    'comments',
    #A blurb of what the talk is about
    'description',
    #The duration of the talk in seconds
    'duration',
    #The number of languages in which the talk is available
    'languages',
    #The official name of the TED Talk. Includes the title and the speaker.
    'name',
    #The ratings and reviews received
    'ratings',
    #Occupation of the Speaker
    'speaker_occupation',
    #Categories in which the Talk falls in
    'tags',
    #The number of views
    'views'
]

# %%
ted_talks_df = ted_talks_raw_df[selected_columns].copy()
ted_talks_df = ted_talks_df.set_index('name')
ted_talks_df
# Out:
#                                                     comments  \
# name
# Ken Robinson: Do schools kill creativity?               4553
# Al Gore: Averting the climate crisis                     265
# David Pogue: Simplicity sells                            124
# Majora Carter: Greening the ghetto                       200
# Hans Rosling: The best stats you've ever seen            593
# ...                                                      ...
# Duarte Geraldino: What we're missing in the deb...        17
# Armando Azua-Bustos: The most Martian place on ...         6
# Radhika Nagpal: What intelligent machines can l...        10
# Theo E.J. Wilson: A black man goes undercover i...        32
# Karoliina Korppoo: How a video game might help ...         8
#
#                                                                                           description  \
# name
# Ken Robinson: Do schools kill creativity?           Sir Ken Robinson makes an entertaining and pro...
# Al Gore: Averting the climate crisis                With the same humor and humanity he exuded in ...
# David Pogue: Simplicity sells                       New York Times columnist David Pogue takes aim...
# Majora Carter: Greening the ghetto                  In an emotionally charged talk, MacArthur-winn...
# Hans Rosling: The best stats you've ever seen       You've never seen data presented like this. Wi...
# ...                                                                                               ...
# Duarte Geraldino: What we're missing in the deb...  Between 2008 and 2016, the United States depor...
# Armando Azua-Bustos: The most Martian place on ...  How can you study Mars without a spaceship? He...
# Radhika Nagpal: What intelligent machines can l...  Science fiction visions of the future show us ...
# Theo E.J. Wilson: A black man goes undercover i...  In an unmissable talk about race and politics ...
# Karoliina Korppoo: How a video game might help ...  With more than half of the world population li...
#
#                                                     duration  languages  \
# name
# Ken Robinson: Do schools kill creativity?               1164         60
# Al Gore: Averting the climate crisis                     977         43
# David Pogue: Simplicity sells                           1286         26
# Majora Carter: Greening the ghetto                      1116         35
# Hans Rosling: The best stats you've ever seen           1190         48
# ...                                                      ...        ...
# Duarte Geraldino: What we're missing in the deb...       476          4
# Armando Azua-Bustos: The most Martian place on ...       290          3
# Radhika Nagpal: What intelligent machines can l...       651          1
# Theo E.J. Wilson: A black man goes undercover i...      1100          1
# Karoliina Korppoo: How a video game might help ...       519          1
#
#                                                                                               ratings  \
# name
# Ken Robinson: Do schools kill creativity?           [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# Al Gore: Averting the climate crisis                [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# David Pogue: Simplicity sells                       [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# Majora Carter: Greening the ghetto                  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# Hans Rosling: The best stats you've ever seen       [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# ...                                                                                               ...
# Duarte Geraldino: What we're missing in the deb...  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# Armando Azua-Bustos: The most Martian place on ...  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# Radhika Nagpal: What intelligent machines can l...  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# Theo E.J. Wilson: A black man goes undercover i...  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# Karoliina Korppoo: How a video game might help ...  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                                                       speaker_occupation  \
# name
# Ken Robinson: Do schools kill creativity?                                Author/educator
# Al Gore: Averting the climate crisis                                    Climate advocate
# David Pogue: Simplicity sells                                       Technology columnist
# Majora Carter: Greening the ghetto                    Activist for environmental justice
# Hans Rosling: The best stats you've ever seen       Global health expert; data visionary
# ...                                                                                  ...
# Duarte Geraldino: What we're missing in the deb...                            Journalist
# Armando Azua-Bustos: The most Martian place on ...                        Astrobiologist
# Radhika Nagpal: What intelligent machines can l...                     Robotics engineer
# Theo E.J. Wilson: A black man goes undercover i...                   Public intellectual
# Karoliina Korppoo: How a video game might help ...                         Game designer
#
#                                                                                                  tags  \
# name
# Ken Robinson: Do schools kill creativity?           ['children', 'creativity', 'culture', 'dance',...
# Al Gore: Averting the climate crisis                ['alternative energy', 'cars', 'climate change...
# David Pogue: Simplicity sells                       ['computers', 'entertainment', 'interface desi...
# Majora Carter: Greening the ghetto                  ['MacArthur grant', 'activism', 'business', 'c...
# Hans Rosling: The best stats you've ever seen       ['Africa', 'Asia', 'Google', 'demo', 'economic...
# ...                                                                                               ...
# Duarte Geraldino: What we're missing in the deb...  ['TED Residency', 'United States', 'community'...
# Armando Azua-Bustos: The most Martian place on ...  ['Mars', 'South America', 'TED Fellows', 'astr...
# Radhika Nagpal: What intelligent machines can l...  ['AI', 'ants', 'fish', 'future', 'innovation',...
# Theo E.J. Wilson: A black man goes undercover i...  ['Internet', 'TEDx', 'United States', 'communi...
# Karoliina Korppoo: How a video game might help ...  ['cities', 'design', 'future', 'infrastructure...
#
#                                                        views
# name
# Ken Robinson: Do schools kill creativity?           47227110
# Al Gore: Averting the climate crisis                 3200520
# David Pogue: Simplicity sells                        1636292
# Majora Carter: Greening the ghetto                   1697550
# Hans Rosling: The best stats you've ever seen       12005869
# ...                                                      ...
# Duarte Geraldino: What we're missing in the deb...    450430
# Armando Azua-Bustos: The most Martian place on ...    417470
# Radhika Nagpal: What intelligent machines can l...    375647
# Theo E.J. Wilson: A black man goes undercover i...    419309
# Karoliina Korppoo: How a video game might help ...    391721
#
# [2550 rows x 8 columns]

# %% [markdown]
# Exploratory Analysis and Visualization
# In this section we will mainly focus on the statistics and different relationships between the data in various columns using plots and charts.
#
# Let's begin by importingmatplotlib.pyplot and seaborn.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### Views

# %%
top_views = ted_talks_df.sort_values(by='views',ascending=False).head(20)
top_views[['views']]
# Out:
#                                                        views
# name
# Ken Robinson: Do schools kill creativity?           47227110
# Amy Cuddy: Your body language may shape who you...  43155405
# Simon Sinek: How great leaders inspire action       34309432
# Brené Brown: The power of vulnerability             31168150
# Mary Roach: 10 things you didn't know about orgasm  22270883
# Julian Treasure: How to speak so that people wa...  21594632
# Jill Bolte Taylor: My stroke of insight             21190883
# Tony Robbins: Why we do what we do                  20685401
# James Veitch: This is what happens when you rep...  20475972
# Cameron Russell: Looks aren't everything. Belie...  19787465
# Dan Pink: The puzzle of motivation                  18830983
# Susan Cain: The power of introverts                 17629275
# Pamela Meyer: How to spot a liar                    16861578
# Robert Waldinger: What makes a good life? Lesso...  16601927
# Shawn Achor: The happy secret to better work        16209727
# Pranav Mistry: The thrilling potential of Sixth...  16097077
# David Blaine: How I held my breath for 17 minutes   15601385
# Apollo Robbins: The art of misdirection             15283242
# Tim Urban: Inside the mind of a master procrast...  14745406
# Dan Gilbert: The surprising science of happiness    14689301

# %% [markdown]
# Let us visualize this data in the form of a bar graph, to understand the data better.

# %%
sns.barplot(x='views',y=top_views.index,data=top_views[['views']])
plt.title('Views')
plt.ylabel(None);
plt.xlabel('Views')
# Out:
# Text(0.5, 0, 'Views')

# %% [markdown]
# ### Languages

# %%
sns.lineplot(x='languages',y='views',data=top_views,color='orange')
plt.title('Views vs Number of Languages')
plt.xlabel('Number of Languages')
plt.ylabel('Views')
# Out:
# Text(0, 0.5, 'Views')

# %% [markdown]
# The general trend seems to be that the number of views of the Ted Talk increases with number of languages it is available in. But it is important to notice that there are a few cases where the number of views are high even when the number of languages it is spoken in is low. This may indicate that a majority of people speaking a particular language are interested in a particular topic of Ted Talks!

# %% [markdown]
# ### Comments

# %%
most_comments = ted_talks_df.sort_values(by='comments',ascending=False).head(20)
most_comments[['comments']]
# Out:
#                                                     comments
# name
# Richard Dawkins: Militant atheism                       6404
# Ken Robinson: Do schools kill creativity?               4553
# Sam Harris: Science can answer moral questions          3356
# Jill Bolte Taylor: My stroke of insight                 2877
# David Chalmers: How do you explain consciousness?       2673
# Janet Echelman: Taking imagination seriously            2492
# Lesley Hazleton: On reading the Koran                   2374
# Amy Cuddy: Your body language may shape who you...      2290
# Michael Specter: The danger of science denial           2272
# Simon Sinek: How great leaders inspire action           1930
# Brené Brown: The power of vulnerability                 1927
# Eric X. Li: A tale of two political systems             1640
# Steve Jobs: How to live before you die                  1627
# Elizabeth Gilbert: Your elusive creative genius         1604
# Allan Savory: How to fight desertification and ...      1586
# James Randi: Homeopathy, quackery and fraud             1545
# Sharmeen Obaid-Chinoy: Inside a school for suic...      1502
# Dan Pallotta: The way we think about charity is...      1451
# Ron Finley: A guerilla gardener in South Centra...      1413
# Monica Lewinsky: The price of shame                     1355

# %%
sns.barplot(x='comments',y=most_comments.index,data=most_comments[['comments']])
plt.title('Comments vs Title')
plt.ylabel(None);
plt.xlabel('Comments')
# Out:
# Text(0.5, 0, 'Comments')

# %% [markdown]
# This shows us a very interesting result! All the topics for the above Ted Talks are either controversial topics or open questions which have resulted in a large number of comments where people would have put out their views and opinions.

# %% [markdown]
# ### Categories (Tags)

# %%
category = []
tagsstr=""
for tags in ted_talks_df.tags:
    tagsstr=""
    for ch in tags:
        if ch=='[' or ch==']':
            continue
        elif ch=='\'':
            continue
        else:
            tagsstr=tagsstr+ch
        tagstr=tagsstr.split(',')
    for name in top_views.index:
        for tag in tagstr:
            tag=tag.strip()
            if tag in name:
                category.append(tag)
df = pd.DataFrame(category,columns=['categories'])
df
# Out:
#       categories
# 0     creativity
# 1     technology
# 2        science
# 3     technology
# 4     motivation
# ...          ...
# 2334     science
# 2335         art
# 2336     science
# 2337     science
# 2338     science
#
# [2339 rows x 1 columns]

# %%
category_count = df.categories.value_counts()
category_count
# Out:
# technology       727
# science          567
# art              221
# creativity       189
# happiness        146
# life             111
# potential         73
# mind              71
# work              71
# motivation        63
# language          59
# sight             21
# body language     11
# introvert          5
# vulnerability      4
# Name: categories, dtype: int64

# %%
category_count.plot.bar(color='hotpink')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Asking and Answering Questions
# We will now answer some interesting questions based on the above data.

# %% [markdown]
# ## Q1: What features make a Good Ted Talk?
# Is it the number of comments? The number of languages? Or can it be the duration? Let's find out!

# %%
sns.barplot(x='views',y=top_views.comments,data=top_views)
y=top_views.comments
plt.xticks(rotation=90)
plt.title('Views vs Comments')
plt.ylabel('Number of Comments');
plt.xlabel('Views')
# Out:
# Text(0.5, 0, 'Views')

# %% [markdown]
# There seems to be a fair correlation between the number of comments and the number of views, though there are a few exceptions. Hence, we can conclude that the number of comments is a feature that indicates a good Ted Talk.

# %%
sns.barplot(x='views',y=top_views.languages,data=top_views)
y=top_views.comments
plt.xticks(rotation=90)
plt.title('Views vs Languages')
plt.ylabel('Number of Languages');
plt.xlabel('Views')
# Out:
# Text(0.5, 0, 'Views')

# %% [markdown]
# As the number of languages the Ted Talk is available in the number of views seems to increase (even by intuition this seems to be true).

# %%
sns.barplot(x='views',y=top_views.duration,data=top_views)
y=top_views.comments
plt.xticks(rotation=90)
plt.title('Views vs Duration')
plt.ylabel('Duration');
plt.xlabel('Views')
# Out:
# Text(0.5, 0, 'Views')

# %% [markdown]
# There is no visible trend relating the duration with the number of views. Hence, duration is not a feature that makes a Ted Talk good.

# %% [markdown]
# ### Q2: What kind of topics attract the maximum discussion and debate (in the form of comments)?

# %%
sns.barplot(x='comments',y=most_comments.index,data=most_comments[['comments']])
plt.title('Comments vs Title')
plt.ylabel(None);
plt.xlabel('Comments')
# Out:
# Text(0.5, 0, 'Comments')

# %% [markdown]
# This shows that the Ted Talks about controversial topics and open-ended questions attract the maximum discussion and debate which can be inferred from the number of comments.

# %% [markdown]
# ### Q3: Which themes are most popular amongst TEDsters?

# %%
category_count[0:12].plot.pie()
# Out:
# <AxesSubplot:ylabel='categories'>

# %% [markdown]
# This shows that the categories of science and technology are most sought after. That been said there are a wide-range of topics that also fascinate the community of TEDsters.

# %% [markdown]
# ### Q4: What professional background are the speakers from?

# %%
top_views[['speaker_occupation']]
# Out:
#                                                                                 speaker_occupation
# name
# Ken Robinson: Do schools kill creativity?                                          Author/educator
# Amy Cuddy: Your body language may shape who you...                             Social psychologist
# Simon Sinek: How great leaders inspire action                                    Leadership expert
# Brené Brown: The power of vulnerability                                   Vulnerability researcher
# Mary Roach: 10 things you didn't know about orgasm                                          Writer
# Julian Treasure: How to speak so that people wa...                                Sound consultant
# Jill Bolte Taylor: My stroke of insight                                             Neuroanatomist
# Tony Robbins: Why we do what we do                     Life coach; expert in leadership psychology
# James Veitch: This is what happens when you rep...                             Comedian and writer
# Cameron Russell: Looks aren't everything. Belie...                                           Model
# Dan Pink: The puzzle of motivation                                                  Career analyst
# Susan Cain: The power of introverts                                            Quiet revolutionary
# Pamela Meyer: How to spot a liar                                                      Lie detector
# Robert Waldinger: What makes a good life? Lesso...      Psychiatrist, psychoanalyst and Zen priest
# Shawn Achor: The happy secret to better work                                          Psychologist
# Pranav Mistry: The thrilling potential of Sixth...  Director of research, Samsung Research America
# David Blaine: How I held my breath for 17 minutes                    Illusionist, endurance artist
# Apollo Robbins: The art of misdirection                                            Gentleman thief
# Tim Urban: Inside the mind of a master procrast...                                         Blogger
# Dan Gilbert: The surprising science of happiness                    Psychologist; happiness expert

# %% [markdown]
# This signifies that the speakers come from a wide-range of professions and thus they represent a plethora of fields across the globe!

# %% [markdown]
# ### Q5: What attributes make a Ted Talk amazing?

# %%
qualities = ['entertain','humor','funny','emotion','drama','motivate','motivating','inspire','inspiring','inspiration','technology','storytelling','powerful','interesting','curious']
for description in top_views.description:
    for quality in qualities:
        if quality in description:
            print(quality)
# Out:
# entertain
# inspiration
# powerful
# funny
# powerful
# motivate
# funny
# inspire

# %% [markdown]
# ## Inferences and Conclusion
# TED Talks mainly provide inspirational and educational content that helps individuals look at things from a different perspective. There is a wide variety of TED Talks, ranging from technology to comedy. From the given dataset, we can infer that the popularity of a TED Talk depends on the number of comments and the number of languages available. It is also marked with a good sense of humor, presentation skills and most importantly, choice of topic.
